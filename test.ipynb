# %%
from script import BlackScholes

BlackScholes.valueByBlackScholes(100,100,3,0.3,0.05,'call')
# Out:
# 26.805483596641537

# %%
from script import impliedVolatility
impliedVolatility.implied_volatility(1.9585,2.4,0.04,24/365,16/365, 0.2, 0.0002, 'cut')
# Out:
# 0.5243542666461152

# %%
from script import geometricAsian
geometricAsian.geoAsian(150,120,1,0.3,0.01,10,'put')
# Out:
# 1.4149431107584305

# %%
from script import geometricBasket
geometricBasket.geoBasket(100,100,100,3,0.3,0.3,0.05,0.5,'call')
# Out:
# 22.10209279760944

# %%
from script import binomialTree as bt
bt.binomialTree(50, 52, 2, 0.223144, 0.05, 25, 'put')
# Out:
# 5.451053394058128

# %%
values = []
for i in range(1, 50):
    values.append(bt.binomialTree(50, 52, 2, 0.223144, 0.05, i, 'put'))

# %%
# draw the graph
import matplotlib.pyplot as plt
plt.plot(range(1, 50), values)
plt.xlabel('Number of steps')
plt.ylabel('Option price')
plt.title('Option price vs number of steps')
plt.show()
